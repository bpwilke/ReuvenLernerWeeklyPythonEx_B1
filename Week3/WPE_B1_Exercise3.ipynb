# %% [markdown]
# # Weekly Programming Exercise B1 - EX 2

# %% [markdown]
# This week, we're going to play with files.  Specifically, logfiles.
#
# A lot of the Python developers I teach (and work with) work with logfiles of various sorts, and want to work with those files in various ways.  This week, we'll see how we can turn the logfile into a list of dictionaries, making it easier to manipulate.
#
# For the purposes of this exercise, we'll be looking at one of my favorite files, which I call "mini-access-log.txt".  It is an excerpt from the Apache HTTP server on my computer (lerner.co.il) from several years ago.  You can view and download it from here:
#
#     https://gist.github.com/reuven/5875971
#
# Each line of this logfile looks like the following:
# 67.218.116.165 - - [30/Jan/2010:00:03:18 +0200] "GET /robots.txt HTTP/1.0" 200 99 "-" "Mozilla/5.0 (Twiceler-0.9 http://www.cuil.com/twiceler/robot.html)"
#
# As you can see:
# The fields aren't separated by whitespace, but are still recognizable to a human.
# Each line starts with an IP address.
# Between square brackets, we have the timestamp -- date, time, and then the time zone.
# Following the timestamp, inside of double quotes ("), we have the HTTP request.  You can assume that in this file, all of the request start with the word GET.
#
# There are other fields as well, but these are the ones that interest me.
#
# The exercise is to write a function that, when given a filename, returns a list of dictionaries.  Each dict should have the following keys:
# ip_address, containing the IP address
# timestamp, containing the timestamp (not including the square brackets, but everything inside of them)
# request, containing the HTTP request (not including the double quotes, but everything inside of them)
#
# Thus, the above line from mini-access-log.txt would look like this:
#     {'ip_address': '67.218.116.165',
#      'timestamp': '30/Jan/2010:00:03:18 +0200',
#      'request': 'GET /robots.txt HTTP/1.0'}
#
# We'll transform the file into a list of dicts, each of which looks that.  There are 206 lines in the file, which means that this list will contain 206 dictionaries, each with these three key-value pairs.
#
# Using a regular expression will definitely help here -- but if you don't know regexps, then don't worry; you can still get it to work. That said, it'll be a bit clunky.
#
# I'll be back with a solution on Monday.
#
# Reuven

# %%
def load_doc(filename):
    file = open(filename, 'r')
    text = file.read().splitlines()
    file.close()
    return text

# %%
log = load_doc("mini-access-log.txt")

# %%
def logtolist(log):
    logList = list()
    for line in log:
        currentEntry = dict()
        currentEntry["ip_address"] = line.split(' - - ')[0]
        currentEntry["timestamp"] = line.split('[')[1].split(']')[0]
        currentEntry["request"] = line.split('\"')[1]
        logList.append(currentEntry)
    return logList

# %%
logtolist(log)
# Out:
# [{'ip_address': '67.218.116.165',
#   'timestamp': '30/Jan/2010:00:03:18 +0200',
#   'request': 'GET /robots.txt HTTP/1.0'},
#  {'ip_address': '66.249.71.65',
#   'timestamp': '30/Jan/2010:00:12:06 +0200',
#   'request': 'GET /browse/one_node/1557 HTTP/1.1'},
#  {'ip_address': '65.55.106.183',
#   'timestamp': '30/Jan/2010:01:29:23 +0200',
#   'request': 'GET /robots.txt HTTP/1.1'},
#  {'ip_address': '65.55.106.183',
#   'timestamp': '30/Jan/2010:01:30:06 +0200',
#   'request': 'GET /browse/one_model/2162 HTTP/1.1'},
#  {'ip_address': '66.249.71.65',
#   'timestamp': '30/Jan/2010:02:07:14 +0200',
#   'request': 'GET /browse/browse_applet_tab/2593 HTTP/1.1'},
#  {'ip_address': '66.249.71.65',
#   'timestamp': '30/Jan/2010:02:10:39 +0200',
#   'request': 'GET /browse/browse_files_tab/2499?tab=true HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:03:13:34 +0200',
#   'request': 'GET /robots.txt HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:03:13:34 +0200',
#   'request': 'GET /browse/one_node/2715 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:03:43:39 +0200',
#   'request': 'GET /browse/download_model/1969 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:04:05:43 +0200',
#   'request': 'GET /browse/one_node/1406 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:04:05:51 +0200',
#   'request': 'GET /browse/one_model/1406 HTTP/1.1'},
#  {'ip_address': '65.55.106.131',
#   'timestamp': '30/Jan/2010:04:24:33 +0200',
#   'request': 'GET /robots.txt HTTP/1.1'},
#  {'ip_address': '65.55.106.131',
#   'timestamp': '30/Jan/2010:04:25:36 +0200',
#   'request': 'GET /browse/one_model/1200 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:04:34:36 +0200',
#   'request': 'GET /browse/download_model/2170 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:04:39:37 +0200',
#   'request': 'GET /browse/browse_preview_tab/2499?tab=true HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:05:03:34 +0200',
#   'request': 'GET /browse/download_model/2244 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:05:32:31 +0200',
#   'request': 'GET /browse/download_model/1002 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:06:01:22 +0200',
#   'request': 'GET /browse/download_model/1200 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:06:30:19 +0200',
#   'request': 'GET /browse/download_model/2463 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:06:59:14 +0200',
#   'request': 'GET /browse/download_model/1861 HTTP/1.1'},
#  {'ip_address': '65.55.106.186',
#   'timestamp': '30/Jan/2010:07:07:13 +0200',
#   'request': 'GET /robots.txt HTTP/1.1'},
#  {'ip_address': '65.55.106.186',
#   'timestamp': '30/Jan/2010:07:08:06 +0200',
#   'request': 'GET /browse/about HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:07:28:09 +0200',
#   'request': 'GET /browse/download_model/1712 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:07:57:06 +0200',
#   'request': 'GET /browse/download_model/1192 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:08:26:00 +0200',
#   'request': 'GET /browse/download_model/1140 HTTP/1.1'},
#  {'ip_address': '74.52.245.146',
#   'timestamp': '30/Jan/2010:08:40:26 +0200',
#   'request': 'GET / HTTP/1.0'},
#  {'ip_address': '74.52.245.146',
#   'timestamp': '30/Jan/2010:08:40:26 +0200',
#   'request': 'GET /account/login HTTP/1.0'},
#  {'ip_address': '66.249.65.43',
#   'timestamp': '30/Jan/2010:08:44:51 +0200',
#   'request': 'GET /robots.txt HTTP/1.1'},
#  {'ip_address': '66.249.65.43',
#   'timestamp': '30/Jan/2010:08:44:52 +0200',
#   'request': 'GET / HTTP/1.1'},
#  {'ip_address': '66.249.65.43',
#   'timestamp': '30/Jan/2010:08:44:52 +0200',
#   'request': 'GET /account/login HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:08:54:53 +0200',
#   'request': 'GET /browse/download_model/2152 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:09:23:46 +0200',
#   'request': 'GET /browse/download_model/796 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:09:52:42 +0200',
#   'request': 'GET /browse/one_node/2177 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:10:21:43 +0200',
#   'request': 'GET /browse/one_node/2163 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:10:50:35 +0200',
#   'request': 'GET /browse/one_node/1193 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:11:19:27 +0200',
#   'request': 'GET /browse/one_node/1241 HTTP/1.1'},
#  {'ip_address': '65.55.207.25',
#   'timestamp': '30/Jan/2010:11:43:56 +0200',
#   'request': 'GET /robots.txt HTTP/1.1'},
#  {'ip_address': '65.55.207.25',
#   'timestamp': '30/Jan/2010:11:44:35 +0200',
#   'request': 'GET /help HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:11:48:31 +0200',
#   'request': 'GET /browse/download_model/2508 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:12:17:24 +0200',
#   'request': 'GET /browse/one_node/2509 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:12:46:17 +0200',
#   'request': 'GET /browse/one_node/1233 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:13:15:09 +0200',
#   'request': 'GET /browse/download_model/2508?version=1819 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:13:44:01 +0200',
#   'request': 'GET /browse/download_model/2508?version=1821 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:14:12:55 +0200',
#   'request': 'GET /browse/download_model/902 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:14:42:01 +0200',
#   'request': 'GET /browse/download_model/1679 HTTP/1.1'},
#  {'ip_address': '65.55.207.94',
#   'timestamp': '30/Jan/2010:15:02:52 +0200',
#   'request': 'GET /robots.txt HTTP/1.1'},
#  {'ip_address': '65.55.207.94',
#   'timestamp': '30/Jan/2010:15:03:36 +0200',
#   'request': 'GET /browse/one_model/900 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:15:10:51 +0200',
#   'request': 'GET /browse/download_model/1612 HTTP/1.1'},
#  {'ip_address': '65.55.207.71',
#   'timestamp': '30/Jan/2010:15:32:04 +0200',
#   'request': 'GET /account/new HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:15:39:45 +0200',
#   'request': 'GET /browse/download_model/892 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:15:52:21 +0200',
#   'request': 'GET /system/avatars/7/thumb/fractal-tree-on-transparent-sm.png?1237131134 HTTP/1.1'},
#  {'ip_address': '66.249.65.12',
#   'timestamp': '30/Jan/2010:16:08:36 +0200',
#   'request': 'GET /browse/download_model/1865 HTTP/1.1'},
#  {'ip_address': '98.242.170.241',
#   'timestamp': '30/Jan/2010:16:10:49 +0200',
#   'request': 'GET /dvdrental.com HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:16:37:33 +0200',
#   'request': 'GET /browse/download_model/914 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:16:45:12 +0200',
#   'request': 'GET /browse/browse_applet_tab/2593?tab=true HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:02:28 +0200',
#   'request': 'GET /javascripts/application.js?1264605648 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:02:29 +0200',
#   'request': 'GET /stylesheets/browse.css?1264605648 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:02:30 +0200',
#   'request': 'GET /javascripts/jquery.livequery.js?1264605648 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:02:30 +0200',
#   'request': 'GET /javascripts/jrails.js?1264605648 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:02:31 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.all.css?1264605648 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:02:31 +0200',
#   'request': 'GET /stylesheets/jquery.autocomplete.css?1264605648 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:02:32 +0200',
#   'request': 'GET /stylesheets/nlcommons.css?1264605648 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:02:32 +0200',
#   'request': 'GET /javascripts/jquery.dataTables.js?1264605648 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:02:33 +0200',
#   'request': 'GET /javascripts/jquery.js?1264605648 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:02:34 +0200',
#   'request': 'GET /javascripts/nlcommons.js?1264605648 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:02:34 +0200',
#   'request': 'GET /javascripts/jquery-ui.js?1264605648 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:02:35 +0200',
#   'request': 'GET /javascripts/jquery.autocomplete.js?1264605648 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:03:16 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.base.css HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:03:16 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.theme.css HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:03:30 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.core.css HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:03:31 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.accordion.css HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:03:31 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.datepicker.css HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:03:32 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.dialog.css HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:03:32 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.slider.css HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:03:33 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.progressbar.css HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:03:34 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.tabs.css HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:03:34 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.resizable.css HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:06:29 +0200',
#   'request': 'GET /browse/download_model/743 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:17:35:24 +0200',
#   'request': 'GET /browse/download_model/2547 HTTP/1.1'},
#  {'ip_address': '65.55.207.126',
#   'timestamp': '30/Jan/2010:17:46:11 +0200',
#   'request': 'GET /robots.txt HTTP/1.1'},
#  {'ip_address': '65.55.207.126',
#   'timestamp': '30/Jan/2010:17:48:32 +0200',
#   'request': 'GET /browse/one_model/1002 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:18:04:31 +0200',
#   'request': 'GET /browse/download_model/1210 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:18:33:30 +0200',
#   'request': 'GET /browse/download_model/849 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:18:53:53 +0200',
#   'request': 'GET /tags/one_tag/27 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:19:02:20 +0200',
#   'request': 'GET /browse/download_model/739 HTTP/1.1'},
#  {'ip_address': '82.34.9.20',
#   'timestamp': '30/Jan/2010:19:18:24 +0200',
#   'request': 'GET /account/models/33 HTTP/1.1'},
#  {'ip_address': '82.34.9.20',
#   'timestamp': '30/Jan/2010:19:18:18 +0200',
#   'request': 'GET /account/models/33 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:19:31:07 +0200',
#   'request': 'GET /browse/download_model/838 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:20:00:20 +0200',
#   'request': 'GET /browse/download_model/2316 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:20:28:55 +0200',
#   'request': 'GET /browse/download_model/840 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:20:47:05 +0200',
#   'request': 'GET /?id=7 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:20:57:43 +0200',
#   'request': 'GET /browse/download_model/806 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:21:07:44 +0200',
#   'request': 'GET /account/mypage/17 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:21:26:36 +0200',
#   'request': 'GET /browse/download_model/1891 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:21:56:01 +0200',
#   'request': 'GET /browse/download_model/1881 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:22:25:13 +0200',
#   'request': 'GET /browse/download_model/735 HTTP/1.1'},
#  {'ip_address': '65.55.106.155',
#   'timestamp': '30/Jan/2010:22:25:26 +0200',
#   'request': 'GET /robots.txt HTTP/1.1'},
#  {'ip_address': '65.55.106.155',
#   'timestamp': '30/Jan/2010:22:26:11 +0200',
#   'request': 'GET /account/send_password HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:22:53:40 +0200',
#   'request': 'GET /browse/download_model/1779 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:23:21:25 +0200',
#   'request': 'GET /browse/follow/2029.atom HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:23:22:21 +0200',
#   'request': 'GET /browse/download_model/788 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:23:28:41 +0200',
#   'request': 'GET /images/default-person.png?1245832850 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '30/Jan/2010:23:53:12 +0200',
#   'request': 'GET /browse/download_model/2340 HTTP/1.1'},
#  {'ip_address': '65.55.207.77',
#   'timestamp': '31/Jan/2010:00:06:37 +0200',
#   'request': 'GET /robots.txt HTTP/1.1'},
#  {'ip_address': '65.55.207.77',
#   'timestamp': '31/Jan/2010:00:09:36 +0200',
#   'request': 'GET /browse/one_model/2152 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:01:15:50 +0200',
#   'request': 'GET /account/follow/2029.atom HTTP/1.1'},
#  {'ip_address': '67.218.116.165',
#   'timestamp': '31/Jan/2010:01:23:08 +0200',
#   'request': 'GET /robots.txt HTTP/1.0'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:01:35:43 +0200',
#   'request': 'GET /browse/one_model/2099 HTTP/1.1'},
#  {'ip_address': '208.80.193.28',
#   'timestamp': '31/Jan/2010:01:50:14 +0200',
#   'request': 'GET / HTTP/1.0'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:02:17:46 +0200',
#   'request': 'GET /browse/download_model/985 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:02:48:17 +0200',
#   'request': 'GET /browse/download_model/2162 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:02:51:11 +0200',
#   'request': 'GET /browse/display_preview/2099 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:03:04:16 +0200',
#   'request': 'GET /browse/download_model/993 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:03:29:31 +0200',
#   'request': 'GET /robots.txt HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:03:29:31 +0200',
#   'request': 'GET /browse/download_model/977 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:03:49:42 +0200',
#   'request': 'GET /tags/one_tag/42 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:03:54:44 +0200',
#   'request': 'GET /browse/download_model/746 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:04:19:51 +0200',
#   'request': 'GET /browse/download_model/815 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:32:52 +0200',
#   'request': 'GET /account/mypage/7 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:03 +0200',
#   'request': 'GET / HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:03 +0200',
#   'request': 'GET /account/login HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:04 +0200',
#   'request': 'GET /browse/list_models HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:05 +0200',
#   'request': 'GET /browse/about HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:06 +0200',
#   'request': 'GET /help HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:06 +0200',
#   'request': 'GET /account/login HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:07 +0200',
#   'request': 'GET /account/follow/7.atom HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:07 +0200',
#   'request': 'GET /browse/one_model/1210 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:08 +0200',
#   'request': 'GET /browse/one_model/1390 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:09 +0200',
#   'request': 'GET /browse/one_model/2495 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:09 +0200',
#   'request': 'GET /browse/one_model/2518 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:10 +0200',
#   'request': 'GET /browse/one_model/1408 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:11 +0200',
#   'request': 'GET /tags/one_tag/48 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:11 +0200',
#   'request': 'GET /tags/one_tag/8 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:12 +0200',
#   'request': 'GET /browse/one_model/815 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:13 +0200',
#   'request': 'GET /browse/one_model/2547 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:13 +0200',
#   'request': 'GET /browse/one_model/1578 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:14 +0200',
#   'request': 'GET /browse/one_model/2510 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:14 +0200',
#   'request': 'GET /browse/one_model/999 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:15 +0200',
#   'request': 'GET /account/models/7 HTTP/1.1'},
#  {'ip_address': '89.248.172.58',
#   'timestamp': '31/Jan/2010:04:33:16 +0200',
#   'request': 'GET /?id=17 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:04:45:02 +0200',
#   'request': 'GET /browse/download_model/2182 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:05:10:16 +0200',
#   'request': 'GET /browse/download_model/900 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:05:17:05 +0200',
#   'request': 'GET /?id=8 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:05:35:29 +0200',
#   'request': 'GET /browse/download_model/797 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:06:00:42 +0200',
#   'request': 'GET /browse/download_model/2606 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:06:03:13 +0200',
#   'request': 'GET /browse/one_model/993 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:06:25:55 +0200',
#   'request': 'GET /browse/download_model/2601 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:06:51:01 +0200',
#   'request': 'GET /browse/download_model/2596 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:07:06:26 +0200',
#   'request': 'GET /browse/display_preview/2244 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:07:16:18 +0200',
#   'request': 'GET /browse/download_model/2752 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:07:41:27 +0200',
#   'request': 'GET /browse/download_model/2492 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:08:06:40 +0200',
#   'request': 'GET /browse/download_model/1408 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:08:31:50 +0200',
#   'request': 'GET /browse/download_model/2511 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:08:56:59 +0200',
#   'request': 'GET /browse/download_model/2479 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:09:22:13 +0200',
#   'request': 'GET /browse/download_model/2754 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:09:47:25 +0200',
#   'request': 'GET /browse/download_model/2751 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:10:12:33 +0200',
#   'request': 'GET /browse/download_model/2656 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:10:30:53 +0200',
#   'request': 'GET /browse/one_node/2701 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:10:37:46 +0200',
#   'request': 'GET /browse/download_model/935 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:11:03:00 +0200',
#   'request': 'GET /browse/download_model/717 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:11:28:14 +0200',
#   'request': 'GET /browse/download_model/751 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:11:53:26 +0200',
#   'request': 'GET /browse/download_model/2549 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:12:18:38 +0200',
#   'request': 'GET /browse/download_model/2650 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:12:43:41 +0200',
#   'request': 'GET /browse/download_model/729 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:12:45:28 +0200',
#   'request': 'GET /browse/browse_applet_tab/2593 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:13:09:00 +0200',
#   'request': 'GET /browse/download_model/814 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:13:34:05 +0200',
#   'request': 'GET /browse/download_model/2629 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:13:59:27 +0200',
#   'request': 'GET /browse/download_model/2644 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:14:24:30 +0200',
#   'request': 'GET /browse/download_model/804 HTTP/1.1'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:44 +0200',
#   'request': 'GET /robots.txt HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:44 +0200',
#   'request': 'GET /account/new HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:47 +0200',
#   'request': 'GET /stylesheets/nlcommons.css?1264605648 HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:50 +0200',
#   'request': 'GET /stylesheets/browse.css?1264605648 HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:52 +0200',
#   'request': 'GET /stylesheets/jquery.autocomplete.css?1264605648 HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:55 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.all.css?1264605648 HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:57 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.theme.css HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:57 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.base.css HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:59 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.slider.css HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:59 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.core.css HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:59 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.tabs.css HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:59 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.accordion.css HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:59 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.dialog.css HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:59 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.resizable.css HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:59 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.datepicker.css HTTP/1.0'},
#  {'ip_address': '67.195.112.35',
#   'timestamp': '31/Jan/2010:14:45:59 +0200',
#   'request': 'GET /stylesheets/themes/nlcommons/ui.progressbar.css HTTP/1.0'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:14:49:40 +0200',
#   'request': 'GET /browse/download_model/1420 HTTP/1.1'},
#  {'ip_address': '65.55.207.50',
#   'timestamp': '31/Jan/2010:15:07:49 +0200',
#   'request': 'GET /robots.txt HTTP/1.1'},
#  {'ip_address': '65.55.207.50',
#   'timestamp': '31/Jan/2010:15:09:06 +0200',
#   'request': 'GET / HTTP/1.1'},
#  {'ip_address': '65.55.207.50',
#   'timestamp': '31/Jan/2010:15:09:14 +0200',
#   'request': 'GET /account/login HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:15:14:55 +0200',
#   'request': 'GET /browse/download_model/766 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:15:40:01 +0200',
#   'request': 'GET /browse/download_model/756 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:16:05:28 +0200',
#   'request': 'GET /browse/download_model/757 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:16:30:36 +0200',
#   'request': 'GET /browse/download_model/725 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:16:55:37 +0200',
#   'request': 'GET /browse/download_model/2473 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:17:20:49 +0200',
#   'request': 'GET /browse/download_model/1510 HTTP/1.1'},
#  {'ip_address': '65.55.215.75',
#   'timestamp': '31/Jan/2010:17:39:03 +0200',
#   'request': 'GET /robots.txt HTTP/1.1'},
#  {'ip_address': '65.55.215.75',
#   'timestamp': '31/Jan/2010:17:40:02 +0200',
#   'request': 'GET /browse/list_models HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:17:46:08 +0200',
#   'request': 'GET /browse/download_model/802 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:18:11:17 +0200',
#   'request': 'GET /browse/download_model/2194 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:18:36:25 +0200',
#   'request': 'GET /browse/download_model/1572 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:19:01:55 +0200',
#   'request': 'GET /browse/download_model/1806 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:19:26:45 +0200',
#   'request': 'GET /browse/download_model/930 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:19:52:00 +0200',
#   'request': 'GET /browse/download_model/2041 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:20:17:07 +0200',
#   'request': 'GET /browse/download_model/1800 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:20:42:19 +0200',
#   'request': 'GET /browse/one_node/1613 HTTP/1.1'},
#  {'ip_address': '66.249.65.38',
#   'timestamp': '31/Jan/2010:21:08:00 +0200',
#   'request': 'GET /browse/one_node/1892 HTTP/1.1'}]
